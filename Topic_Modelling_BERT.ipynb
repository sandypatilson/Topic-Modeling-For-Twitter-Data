# %%
# !pip install bertopic
import pandas as pd
import re

# %%
df=pd.read_csv('/content/Mental-Health-Twitter.csv')

# %%
df.info()

# %%
df["Clean Text"] = df["post_text"].apply(cleanText)

# %%
def cleanText(text):
  #newText = re.sub(r"s\b"," is", text)
  newText = re.sub("#", " ", text)
  newText = re.sub("@[A-Za-z0-9]+", " ", newText)
  newText = re.sub(r"http\S+", " ", newText)
  newText = re.sub(r"[^a-zA-Z]", " ", newText)
  newText = newText.lower().strip()
  return newText

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# we add this to remove stopwords, for lower volumes of data stopwords can cause issues
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")


# deal with df if needed
if type(df['Clean Text']) is list:
    text = df['Clean Text']
else:
    text = df['Clean Text'].tolist()

# initialize the model
model = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english', calculate_probabilities=True,
    verbose=True
)
topics, probs = model.fit_transform(text)
# Out:
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]
# 2023-03-21 12:03:06,173 - BERTopic - Transformed documents to Embeddings
# 2023-03-21 12:03:26,392 - BERTopic - Reduced dimensionality
# 2023-03-21 12:05:56,322 - BERTopic - Clustered reduced embeddings

# %%
for i in range(10):
    print(f"{topics[i]}: {df['Clean Text'][i]}")
# Out:
# 0: it s just over   years since i was diagnosed with  anxiety and  depression  today i m taking a moment to reflect on how far i ve come since
# -1: it s sunday  i need a break  so i m planning to spend as little time as possible on the  a
# 11: awake but tired  i need to sleep but my brain has other ideas
# -1: rt     retro bears make perfect gifts and are great for beginners too  get stitching with october s sew on sale now   yay
# 257: it s hard to say whether packing lists are making life easier or just reinforcing how much still needs doing     movinghouse  anxiety
# 257: making packing lists is my new hobby     movinghouse
# 257: at what point does keeping stuff for nostalgic reasons cross the line into plain old hoarding      movinghouse
# 257: currently in the finding boxes of random shit packing phase  i think i m a closet hoarder
# 4: can t be bothered to cook  take away on the way      lazy
# 1: rt    itv releases promo video for the final series of downton abbey

# %%
freq = model.get_topic_info()
freq.head(10)
# Out:
#    Topic  Count                                               Name
# 0     -1   6859                              -1_trump_just_like_rt
# 1      0    815  0_depression_depression treatments_treatments_...
# 2      1    657                          1_rt_rt rt_rt daily_daily
# 3      2    490        2_user_business user_com user_user business
# 4      3    325  3_twitter thank_following twitter_following_sa...
# 5      4    190                            4_pizza_food_eat_hungry
# 6      5    187              5_shes_talk_piece toosoon_took little
# 7      6    186                     6_tweet_twitter_tweets_retweet
# 8      7    169                                 7_cat_dog_cats_pet
# 9      8    138                8_migraine_migraines_prevent_ocular

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_hierarchy()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.topic_labels_
# Out:
# {-1: '-1_trump_just_like_rt',
#  0: '0_depression_depression treatments_treatments_overcome',
#  1: '1_rt_rt rt_rt daily_daily',
#  2: '2_user_business user_com user_user business',
#  3: '3_twitter thank_following twitter_following_say hello',
#  4: '4_pizza_food_eat_hungry',
#  5: '5_shes_talk_piece toosoon_took little',
#  6: '6_tweet_twitter_tweets_retweet',
#  7: '7_cat_dog_cats_pet',
#  8: '8_migraine_migraines_prevent_ocular',
#  9: '9_parenting_children_child_abuse',
#  10: '10_lightsaber_saber_lightsabers_sabers',
#  11: '11_sleep_asleep_awake_nap',
#  12: '12_nbavote_nbavote rt_isaiah_harden',
#  13: '13_amp_guitar_air guitar_rt amp',
#  14: '14_tak_malay_dia_malaysia',
#  15: '15_mental_mental health_health_illness',
#  16: '16_album_music_song_new album',
#  17: '17_girls_girlfriend_girl_sex homie',
#  18: '18_addiction_heroin_drug_addicted',
#  19: '19_foryong_wearepayting foryong_wearepayting_foryong rt',
#  20: '20_watch_episode_movie_series',
# ...

# %%
# Out:
# 20000
